# %%
import pandas as pd
train_csv=pd.read_csv('TrainL1C.csv')

# %%
train_csv
# Out:
#            1  718.4586667  22256928   56812   7724107  238700  151438    1044  \
# 0          2    25.521137   4239408  105695   5844288  188902  264008  113582
# 1          3   268.288044   6708500   87686  13008485   19704  150505   38501
# 2          4   209.071599  36835247   70791   2520814  200111  253458   53719
# 3          5  3482.169185  23693467   75610   9276779   65532  278877   95178
# 4          6    55.181083  13925382  114740   2733356  264751  112292  145635
# 5          7     6.854792   9003238  114781  11897392  414701  213302   54295
# 6          8   869.322366  28305816   75470   6150648   40533  339485   19815
# 7          9   174.659939  22598871   43627   2999952  135596  258361  135905
# 8         10    78.817738  11229177  100429     77322  280313  120282  145128
# 9         11   948.722892  35568418  115363   9525587  153330  323874   83532
# 10        12  5071.807808  22007584   49056   9725803  343281  191588  128035
# ...

# %%
train2=pd.read_csv('TrainL2.csv')

# %%
train2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04d7f189627d> in <module>
# ----> 1 train2
#
# NameError: name 'train2' is not defined

# %%
import matplotlib.pyplot as plt

# %%
train2.plot(x='EQ',y='Trade_Invest')

# %%
import arviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-177c8f3773e7> in <module>
# ----> 1 import arviz
#
# ModuleNotFoundError: No module named 'arviz'

# %%
from sklearn import preprocessing
x = train2[['Trade_Invest']].values.astype(float)
y = train2[['EQ']].values.astype(float)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
y_scaled = min_max_scaler.fit_transform(y)
x_normalized = pd.DataFrame(x_scaled)
y_normalized = pd.DataFrame(y_scaled)

# %%
plt.xlabel('x_normalized')
plt.ylabel('y_normalized')
plt.plot(x_normalized,y_normalized)

# %%
y_normalized
# Out:
#               0
# 0      0.038714
# 1      0.001374
# 2      0.014456
# 3      0.011265
# 4      0.187641
# 5      0.002972
# 6      0.000368
# 7      0.046844
# 8      0.009411
# 9      0.004246
# 10     0.051122
# 11     0.273301
# 12     0.107196
# 13     0.008923
# 14     0.008592
# 15     0.088659
# 16     0.000152
# 17     0.017148
# 18     0.000810
# 19     0.042897
# 20     0.000144
# 21     0.016292
# 22     0.000594
# 23     0.017619
# 24     0.006123
# 25     0.034054
# 26     0.014615
# 27     0.002117
# 28     0.000747
# 29     0.001162
# ...         ...
# 11970  0.007505
# 11971  0.011326
# 11972  0.018966
# 11973  0.116950
# 11974  0.002356
# 11975  0.000197
# 11976  0.001374
# 11977  0.002435
# 11978  0.004569
# 11979  0.057588
# 11980  0.016129
# 11981  0.002067
# 11982  0.043120
# 11983  0.058616
# 11984  0.001678
# 11985  0.011892
# 11986  0.012037
# 11987  0.085789
# 11988  0.045747
# 11989  0.013552
# 11990  0.006176
# 11991  0.001858
# 11992  0.010530
# ...

# %%
import numpy as np
train2.set_index(np.arange(len(train2)) // 30).mean(level=0)
# Out:
#          Day           EQ  Social_Search_Impressions  \
# 0       15.5   624.516986               1.714106e+07
# 1       45.5   305.150067               1.662076e+07
# 2       75.5  1040.161381               2.332838e+07
# 3      105.5   859.039145               1.835150e+07
# 4      135.5  1015.289450               2.165741e+07
# 5      165.5   595.103506               1.991307e+07
# 6      195.5   491.619397               1.980835e+07
# 7      225.5   875.012610               1.900154e+07
# 8      255.5   396.599392               1.910112e+07
# 9      285.5  1072.671578               2.037619e+07
# 10     315.5   302.363221               1.890827e+07
# 11     345.5   997.437185               2.065744e+07
# 12     375.5   781.927015               2.103194e+07
# 13     405.5   592.729196               2.045122e+07
# 14     435.5   270.858533               1.789994e+07
# 15     465.5   671.798727               2.071716e+07
# 16     495.5   581.714981               1.712586e+07
# ...

# %%
train2.plot(x='EQ',y='Trade_Invest')

# %%
train2.plot(y='EQ',x='Trade_Invest')

# %%
train2['EQ']
# Out:
# 0         718.458667
# 1          25.521137
# 2         268.288044
# 3         209.071599
# 4        3482.169185
# 5          55.181083
# 6           6.854792
# 7         869.322366
# 8         174.659939
# 9          78.817738
# 10        948.722892
# 11       5071.807808
# 12       1989.307549
# 13        165.600147
# 14        159.474613
# 15       1645.314275
# 16          2.846392
# 17        318.238206
# 18         15.042321
# 19        796.083257
# 20          2.696152
# 21        302.359607
# 22         11.047163
# 23        326.979072
# 24        113.638465
# 25        631.983469
# 26        271.241164
# 27         39.312455
# 28         13.883740
# 29         21.586273
#             ...
# 11970     139.302725
# 11971     210.199841
# 11972     351.975893
# 11973    2170.333263
# 11974      43.735044
# 11975       3.683667
# 11976      25.520790
# 11977      45.213146
# 11978      84.807786
# 11979    1068.716080
# 11980     299.329227
# 11981      38.371202
# ...

# %%
train2.set_index(np.arange(len(train2)) // 30).mean(level=0)
# Out:
#          Day           EQ  Social_Search_Impressions  \
# 0       15.5   624.516986               1.714106e+07
# 1       45.5   305.150067               1.662076e+07
# 2       75.5  1040.161381               2.332838e+07
# 3      105.5   859.039145               1.835150e+07
# 4      135.5  1015.289450               2.165741e+07
# 5      165.5   595.103506               1.991307e+07
# 6      195.5   491.619397               1.980835e+07
# 7      225.5   875.012610               1.900154e+07
# 8      255.5   396.599392               1.910112e+07
# 9      285.5  1072.671578               2.037619e+07
# 10     315.5   302.363221               1.890827e+07
# 11     345.5   997.437185               2.065744e+07
# 12     375.5   781.927015               2.103194e+07
# 13     405.5   592.729196               2.045122e+07
# 14     435.5   270.858533               1.789994e+07
# 15     465.5   671.798727               2.071716e+07
# 16     495.5   581.714981               1.712586e+07
# ...

# %%
newtrain=train2.set_index(np.arange(len(train2)) // 30).mean(level=0)

# %%
newtrain
# Out:
#          Day           EQ  Social_Search_Impressions  \
# 0       15.5   624.516986               1.714106e+07
# 1       45.5   305.150067               1.662076e+07
# 2       75.5  1040.161381               2.332838e+07
# 3      105.5   859.039145               1.835150e+07
# 4      135.5  1015.289450               2.165741e+07
# 5      165.5   595.103506               1.991307e+07
# 6      195.5   491.619397               1.980835e+07
# 7      225.5   875.012610               1.900154e+07
# 8      255.5   396.599392               1.910112e+07
# 9      285.5  1072.671578               2.037619e+07
# 10     315.5   302.363221               1.890827e+07
# 11     345.5   997.437185               2.065744e+07
# 12     375.5   781.927015               2.103194e+07
# 13     405.5   592.729196               2.045122e+07
# 14     435.5   270.858533               1.789994e+07
# 15     465.5   671.798727               2.071716e+07
# 16     495.5   581.714981               1.712586e+07
# ...

# %%
newtrain['EQ']
# Out:
# 0       624.516986
# 1       305.150067
# 2      1040.161381
# 3       859.039145
# 4      1015.289450
# 5       595.103506
# 6       491.619397
# 7       875.012610
# 8       396.599392
# 9      1072.671578
# 10      302.363221
# 11      997.437185
# 12      781.927015
# 13      592.729196
# 14      270.858533
# 15      671.798727
# 16      581.714981
# 17      687.155370
# 18      731.998221
# 19      556.959688
# 20      661.997498
# 21      455.141172
# 22      669.564757
# 23     1178.883183
# 24      628.012759
# 25      620.667415
# 26     1075.760958
# 27      793.782018
# 28     1588.235700
# 29      340.250927
#           ...
# 370     392.144943
# 371     632.510177
# 372     704.736695
# 373     448.702649
# 374     654.546618
# 375     677.050968
# 376     460.406906
# 377     897.914901
# 378     551.780897
# 379     467.715818
# 380     514.280722
# 381     458.820024
# 382     860.567322
# 383     301.651579
# 384     880.905197
# 385     720.157657
# ...

# %%
newtrain.plot(y='EQ',x='Trade_Invest')

# %%
import pandas as pd
import numpy as np
train2=pd.read_csv('TrainL2.csv')
newt2=train2.set_index(np.arange(len(train2))//500).mean(level=0)
newt2.plot(y='EQ',x='Avg_EQ_Price')

# %%
import matplotlib.pyplot as plt
y=newt2['EQ']
x=newt2['Avg_EQ_Price']
plt.scatter(x,y)

# %%
y=newt2['EQ']
x=newt2['Inflation']
plt.scatter(x,y)

# %%
newt2.plot(y='EQ',x='Est_ACV_Selling')
